# %% [markdown]
# ## Importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import warnings
warnings.filterwarnings('ignore')

# %%
df_am=pd.read_csv('amz_com-ecommerce_sample.csv',encoding= 'unicode_escape')

# %%
df_fl=pd.read_csv('flipkart_com-ecommerce_sample.csv',encoding= 'unicode_escape')

# %%
df_am.head()
# Out:
#                             uniq_id            crawl_timestamp  \
# 0  c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1  7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2  f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3  0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4  bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
#
#                                          product_url  \
# 0  http://www.flipkart.com/alisha-solid-women-s-c...
# 1  http://www.flipkart.com/fabhomedecor-fabric-do...
# 2  http://www.flipkart.com/aw-bellies/p/itmeh4grg...
# 3  http://www.flipkart.com/alisha-solid-women-s-c...
# 4  http://www.flipkart.com/sicons-all-purpose-arn...
#
#                   product name on amazon  \
# 0    Alisha Solid Women's Cycling Shorts
# 1    FabHomeDecor Fabric Double Sofa Bed
# 2                             AW Bellies
# 3    Alisha Solid Women's Cycling Shorts
# 4  Sicons All Purpose Arnica Dog Shampoo
#
# ...

# %%
df_fl.head()
# Out:
#                             uniq_id            crawl_timestamp  \
# 0  c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1  7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2  f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3  0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4  bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
#
#                                          product_url  \
# 0  http://www.flipkart.com/alisha-solid-women-s-c...
# 1  http://www.flipkart.com/fabhomedecor-fabric-do...
# 2  http://www.flipkart.com/aw-bellies/p/itmeh4grg...
# 3  http://www.flipkart.com/alisha-solid-women-s-c...
# 4  http://www.flipkart.com/sicons-all-purpose-arn...
#
#                 product name on flipkart  \
# 0    Alisha Solid Women's Cycling Shorts
# 1    FabHomeDecor Fabric Double Sofa Bed
# 2                             AW Bellies
# 3    Alisha Solid Women's Cycling Shorts
# 4  Sicons All Purpose Arnica Dog Shampoo
#
# ...

# %%
df_am.columns
# Out:
# Index(['uniq_id', 'crawl_timestamp', 'product_url', 'product_name',
#        'product_category_tree', 'pid', 'retail_price', 'discounted_price',
#        'image', 'is_FK_Advantage_product', 'description', 'product_rating',
#        'overall_rating', 'brand', 'product_specifications'],
#       dtype='object')

# %%
df_am.describe()
# Out:
#         retail_price  discounted_price
# count   20000.000000       20000.00000
# mean     2957.095150        2364.59705
# std      8993.993257        8994.62368
# min       -20.000000           0.00000
# 25%       647.000000         424.00000
# 50%       999.000000         663.00000
# 75%      1986.000000        1235.00000
# max    571223.000000      726879.00000

# %%
df_fl.describe()
# Out:
#         retail_price  discounted_price
# count   19922.000000      19922.000000
# mean     2979.206104       1973.401767
# std      9009.639341       7333.586040
# min        35.000000         35.000000
# 25%       666.000000        350.000000
# 50%      1040.000000        550.000000
# 75%      1999.000000        999.000000
# max    571230.000000     571230.000000

# %% [markdown]
# ## Renaming columns

# %%
df_am.rename(columns = {'product_name':'product name on amazon','retail_price':'retail price on amazon', 'discounted_price':'discounted price on amazon',}, inplace = True)

# %%
df_fl.rename(columns = {'product_name':'product name on flipkart','retail_price':'retail price on flipkart', 'discounted_price':'discounted price on flipkart',}, inplace = True)

# %%
df_fl.head()
# Out:
#                             uniq_id            crawl_timestamp  \
# 0  c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1  7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2  f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3  0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4  bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
#
#                                          product_url  \
# 0  http://www.flipkart.com/alisha-solid-women-s-c...
# 1  http://www.flipkart.com/fabhomedecor-fabric-do...
# 2  http://www.flipkart.com/aw-bellies/p/itmeh4grg...
# 3  http://www.flipkart.com/alisha-solid-women-s-c...
# 4  http://www.flipkart.com/sicons-all-purpose-arn...
#
#                 product name on flipkart  \
# 0    Alisha Solid Women's Cycling Shorts
# 1    FabHomeDecor Fabric Double Sofa Bed
# 2                             AW Bellies
# 3    Alisha Solid Women's Cycling Shorts
# 4  Sicons All Purpose Arnica Dog Shampoo
#
# ...

# %%
df_am.head()
# Out:
#                             uniq_id            crawl_timestamp  \
# 0  c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1  7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2  f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3  0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4  bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
#
#                                          product_url  \
# 0  http://www.flipkart.com/alisha-solid-women-s-c...
# 1  http://www.flipkart.com/fabhomedecor-fabric-do...
# 2  http://www.flipkart.com/aw-bellies/p/itmeh4grg...
# 3  http://www.flipkart.com/alisha-solid-women-s-c...
# 4  http://www.flipkart.com/sicons-all-purpose-arn...
#
#                   product name on amazon  \
# 0    Alisha Solid Women's Cycling Shorts
# 1    FabHomeDecor Fabric Double Sofa Bed
# 2                             AW Bellies
# 3    Alisha Solid Women's Cycling Shorts
# 4  Sicons All Purpose Arnica Dog Shampoo
#
# ...

# %% [markdown]
# ## Merging the datasets

# %%
merged_df=pd.merge(df_fl, df_am, on=['uniq_id','pid'])

# %%
merged_df
# Out:
#                                 uniq_id          crawl_timestamp_x  \
# 0      c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1      7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2      f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3      0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4      bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
# ...                                 ...                        ...
# 19995  7179d2f6c4ad50a17d014ca1d2815156  2015-12-01 10:15:43 +0000
# 19996  71ac419198359d37b8fe5e3fffdfee09  2015-12-01 10:15:43 +0000
# 19997  93e9d343837400ce0d7980874ece471c  2015-12-01 10:15:43 +0000
# 19998  669e79b8fa5d9ae020841c0c97d5e935  2015-12-01 10:15:43 +0000
# 19999  cb4fa87a874f715fff567f7b7b3be79c  2015-12-01 10:15:43 +0000
#
#                                            product_url_x  \
# 0      http://www.flipkart.com/alisha-solid-women-s-c...
# ...

# %%
merged_df.columns
# Out:
# Index(['uniq_id', 'crawl_timestamp_x', 'product_url_x',
#        'product name on flipkart', 'product_category_tree_x', 'pid',
#        'retail price on flipkart', 'discounted price on flipkart', 'image_x',
#        'is_FK_Advantage_product_x', 'description_x', 'product_rating_x',
#        'overall_rating_x', 'brand_x', 'product_specifications_x',
#        'crawl_timestamp_y', 'product_url_y', 'product name on amazon',
#        'product_category_tree_y', 'retail price on amazon',
#        'discounted price on amazon', 'image_y', 'is_FK_Advantage_product_y',
#        'description_y', 'product_rating_y', 'overall_rating_y', 'brand_y',
#        'product_specifications_y'],
#       dtype='object')

# %%
new=merged_df.drop(columns=['uniq_id', 'crawl_timestamp_x', 'product_url_x'
       , 'product_category_tree_x', 'pid'
       , 'image_x',
       'is_FK_Advantage_product_x', 'description_x', 'product_rating_x',
       'overall_rating_x', 'brand_x', 'product_specifications_x',
       'crawl_timestamp_y', 'product_url_y', 
       'product_category_tree_y', 
        'image_y', 'is_FK_Advantage_product_y',
       'description_y', 'product_rating_y', 'overall_rating_y', 'brand_y',
       'product_specifications_y'
       ])

# %%
new
# Out:
#                       product name on flipkart  retail price on flipkart  \
# 0          Alisha Solid Women's Cycling Shorts                     999.0
# 1          FabHomeDecor Fabric Double Sofa Bed                   32157.0
# 2                                   AW Bellies                     999.0
# 3          Alisha Solid Women's Cycling Shorts                     699.0
# 4        Sicons All Purpose Arnica Dog Shampoo                     220.0
# ...                                        ...                       ...
# 19995           WallDesign Small Vinyl Sticker                    1500.0
# 19996  Wallmantra Large Vinyl Stickers Sticker                    1429.0
# 19997  Elite Collection Medium Acrylic Sticker                    1299.0
# 19998  Elite Collection Medium Acrylic Sticker                    1499.0
# 19999  Elite Collection Medium Acrylic Sticker                    1499.0
#
#        discounted price on flipkart                   product name on amazon  \
# ...

# %% [markdown]
# ## Generating output file

# %%
new.to_csv('output.csv')
